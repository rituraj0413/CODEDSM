# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.rand(50)
# Out:
# array([0.7724418 , 0.30314344, 0.08139246, 0.69819694, 0.17391296,
#        0.14791756, 0.69947557, 0.28353933, 0.5237313 , 0.67706346,
#        0.86803139, 0.93083081, 0.36001743, 0.03867321, 0.25839205,
#        0.59593602, 0.22059527, 0.85739439, 0.21878037, 0.02686559,
#        0.15673936, 0.44921229, 0.24279616, 0.03584311, 0.92060897,
#        0.78209449, 0.78260221, 0.7300804 , 0.27098468, 0.63091521,
#        0.33619014, 0.58745856, 0.36067779, 0.88539562, 0.06948194,
#        0.3123292 , 0.92859487, 0.48314725, 0.93651931, 0.32309207,
#        0.99193388, 0.1972628 , 0.27316282, 0.83584325, 0.01355485,
#        0.73573575, 0.2625566 , 0.86820871, 0.66203606, 0.07565234])

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.8865971 , 0.48362795, 0.59637943, 0.66444968, 0.81213001,
#        0.44228024, 0.62270487, 0.60267304, 0.40309443, 0.31364376,
#        0.99146583, 0.25658174, 0.40492302, 0.05629601, 0.03001944,
#        0.9286241 , 0.439579  , 0.07244741, 0.99887585, 0.64463441,
#        0.00786036, 0.2345094 , 0.51544208, 0.92732858, 0.26076946,
#        0.7572971 , 0.7591735 , 0.34166137, 0.47384484, 0.78511309,
#        0.24705029, 0.41826963, 0.73125719, 0.9096439 , 0.99018528,
#        0.04627722, 0.97942496, 0.26624054, 0.50762164, 0.62737816,
#        0.60377118, 0.87087626, 0.43478798, 0.57475815, 0.78546478,
#        0.98058139, 0.24247926, 0.20583984, 0.07947691, 0.72587066])

# %%
y
# Out:
# array([0.98949283, 0.90772793, 0.246698  , 0.69291078, 0.68608414,
#        0.44144586, 0.82935743, 0.79962738, 0.43963011, 0.49866489,
#        0.35448245, 0.73338475, 0.80099433, 0.25615535, 0.78030478,
#        0.74665011, 0.6638308 , 0.31016176, 0.61604964, 0.14876368,
#        0.57683741, 0.07390883, 0.21135001, 0.81702245, 0.33324742,
#        0.02311893, 0.00470993, 0.83409401, 0.34639002, 0.60966561,
#        0.89131459, 0.22577269, 0.79181535, 0.26883572, 0.43746542,
#        0.6286802 , 0.58782744, 0.67012609, 0.98328401, 0.07949114,
#        0.26715617, 0.68427318, 0.84064484, 0.6609911 , 0.03152968,
#        0.70691635, 0.74988952, 0.21146465, 0.67131801, 0.03495859])

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y , c = "r", alpha = 0.9,marker= "x")
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is x vs y")
plt.grid()

# %%
x= np.linspace(1,10 , 100)
y= np.sin(x)

# %%
x
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
y
# Out:
# array([ 0.84147098,  0.88704699,  0.92529707,  0.95590534,  0.978619  ,
#         0.99325047,  0.99967891,  0.99785123,  0.98778253,  0.96955595,
#         0.94332203,  0.90929743,  0.86776314,  0.8190622 ,  0.76359681,
#         0.70182505,  0.63425707,  0.56145091,  0.48400786,  0.40256749,
#         0.31780241,  0.23041267,  0.14112001,  0.05066187, -0.04021468,
#        -0.1307591 , -0.22022362, -0.30786935, -0.39297247, -0.47483011,
#        -0.55276624, -0.6261372 , -0.69433703, -0.7568025 , -0.8130177 ,
#        -0.86251837, -0.9048957 , -0.93979971, -0.96694212, -0.98609877,
#        -0.99711147, -0.99988924, -0.99440916, -0.98071647, -0.95892427,
#        -0.92921254, -0.89182665, -0.84707537, -0.79532828, -0.73701276,
#        -0.67261042, -0.60265314, -0.52771868, -0.44842592, -0.36542971,
#        -0.2794155 , -0.19109366, -0.10119362, -0.01045784,  0.0803643 ,
#         0.17052273,  0.25927286,  0.34588171,  0.429634  ,  0.50983804,
# ...

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(8,2))
plt.plot(x,y , '--r')
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is my sinx graph")
plt.grid()

# %%
x = ['a' , 'b', 'c', 'd', 'e']
y= np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.1873143 , 0.08096401, 0.03815836, 0.30832796, 0.53829902])

# %%
plt.figure(figsize=(5,3))
plt.bar(x,y)
plt.xlabel("represecnting my cat data")
plt.ylabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
plt.figure(figsize=(5,3))
plt.barh(x,y)
plt.ylabel("represecnting my cat data")
plt.xlabel("representing my num data")
plt.title("this is my bar plot")
plt.grid()

# %%
x = [3,4,5,6,7,8]
y = [4,5,6,7,8,9]

# %%
plt.figure(figsize=(5,6))
plt.plot(x,y)

# %%
data= [1,2,3,4,5,6,6,7,7,8,8,8,8,]

# %%
plt.hist(data)
plt.figure(figsize=(6,3))
plt.xlabel("represecnting unique value")
plt.ylabel("representing frequency")
plt.title("history plot example")
plt.grid()
plt.savefig('test.jpg')

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)
fig=plt.figure()
ax=fig.add_subplot(projection = '3d')
ax.scatter(x,y,z, c = 'r', alpha = 0.9)
plt.show()
