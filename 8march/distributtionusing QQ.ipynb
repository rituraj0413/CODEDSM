# %% [markdown]
# check normal distribution using QQ plot-Quantile Quantile- plot

# %%
import scipy.stats as stats
import pylab
import numpy as np

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

# %%
def plot_data(df,feature):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(df[feature],kde=True)
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot= pylab)
    plt.show()

# %%
plot_data(df,'sepal_width')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/3612836694.py in <module>
# ----> 1 plot_data(df,'sepal_width')
#
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/3067098219.py in plot_data(df, feature)
#       4     sns.histplot(df[feature],kde=True)
#       5     plt.subplot(1,2,2)
# ----> 6     stat.probplot(df[feature],dist='norm',plot= pylab)
#       7     plt.show()
#
# NameError: name 'stat' is not defined

# %%
plot_data(df,'sepal_length')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/2982054334.py in <module>
# ----> 1 plot_data(df,'sepal_length')
#
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/3067098219.py in plot_data(df, feature)
#       4     sns.histplot(df[feature],kde=True)
#       5     plt.subplot(1,2,2)
# ----> 6     stat.probplot(df[feature],dist='norm',plot= pylab)
#       7     plt.show()
#
# NameError: name 'stat' is not defined

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
plot_data(df,'sex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/1726367812.py in <module>
# ----> 1 plot_data(df,'sex')
#
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/3067098219.py in plot_data(df, feature)
#       4     sns.histplot(df[feature],kde=True)
#       5     plt.subplot(1,2,2)
# ----> 6     stat.probplot(df[feature],dist='norm',plot= pylab)
#       7     plt.show()
#
# NameError: name 'stat' is not defined

# %%
plot_data(df,'total_bill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/25515941.py in <module>
# ----> 1 plot_data(df,'total_bill')
#
# /var/folders/fd/hfyxn16n77v2xc3jhkw_7pjc0000gn/T/ipykernel_5505/3067098219.py in plot_data(df, feature)
#       4     sns.histplot(df[feature],kde=True)
#       5     plt.subplot(1,2,2)
# ----> 6     stat.probplot(df[feature],dist='norm',plot= pylab)
#       7     plt.show()
#
# NameError: name 'stat' is not defined
